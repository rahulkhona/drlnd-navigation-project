# %%
import numpy as np
import matplotlib.pyplot as plt
import hyper_parameter_providers as hpp

# %%
x = [ i for i in range(100)]

# %%
cpp = hpp.ConstantParameterProvider(0.5)
y = [cpp.get() for i in range(0, 100)]

# %%
plt.plot(x, y)

# %%
lcpp = hpp.LinearChangeParameterProvider(0.9, 0.1, -0.01)
y=[lcpp.get() for i in range(0, 100)]
plt.plot(x, y)

# %%
lcpp = hpp.LinearChangeParameterProvider(0.1, 0.9, 0.01)
y=[lcpp.get() for i in range(0, 100)]
plt.plot(x, y)

# %%
ecpp = hpp.ExponentialChangeParameterProvider(0.1, 0.9, 0.1)
y=[ecpp.get() for i in range(0, 100)]
plt.plot(x, y)

# %%
ecpp = hpp.ExponentialChangeParameterProvider(0.9, 0.1, -0.1)
y=[ecpp.get() for i in range(0, 100)]
plt.plot(x, y)

# %%
scpp = hpp.ScheduledChangeParameterProvider([10, 20, 30, 40],[0.1, 0.2, 0.4, 0.6])
y=[scpp.get() for i in range(0, 100)]
plt.plot(x, y)
print(y)
# Out:
# [0.1, 0.2, 0.4, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6, 0.6]

# %%
from replay_buffer import ReplayBuffer, PriorityReplayBuffer

# %%
x = ReplayBuffer

# %%
x
# Out:
# replay_buffer.ReplayBuffer

# %%
y = PriorityReplayBuffer

# %%
y
# Out:
# replay_buffer.PriorityReplayBuffer

# %%
type(y)
# Out:
# type

# %%
type(y)
# Out:
# type

# %%
if y == PriorityReplayBuffer:
    print("Yes")
# Out:
# Yes
